# %%
pip install ipyturtle
# Out:
# Running cells with 'Python 3.13.9' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/KWA103744/AppData/Local/Microsoft/WindowsApps/python3.13.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
from ipyturtle import Turtle

t = Turtle()
t.forward(100)
t.left(90)
t.forward(100)
